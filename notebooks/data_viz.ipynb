# %%
from plotly import express as ex
import pandas as pd
import numpy as np
from ipa.scalarization import ReferencePointASF

# %%
datasets = {
    "DTLZ5": "../data/dtlz5_3.csv",
    "DTLZ7": "../data/dtlz7.csv",
    "forest1": "../data/forest_Carb.csv",
    "forest2": "../data/forest_DW.csv",
    "forest3": "../data/forest_HA.csv",
    "forest4": "../data/forest_Rev.csv",
    "RE31": "../data/RE31.csv",
    "RE32": "../data/RE32.csv",
    "RE33": "../data/RE33.csv",
    "RE34": "../data/RE34.csv",
    "RE35": "../data/RE35.csv",
    "RE36": "../data/RE36.csv",
    "RE37": "../data/RE37.csv",
}

data = pd.read_csv(datasets["forest4"])

ex.scatter_3d(
    data,
    x=data.columns[0],
    y=data.columns[1],
    z=data.columns[2],
    )
# Out:
# <div>                            <div id="1aa431a2-06ac-4bd7-a410-52a5e22a56cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1aa431a2-06ac-4bd7-a410-52a5e22a56cc")) {                    Plotly.newPlot(                        "1aa431a2-06ac-4bd7-a410-52a5e22a56cc",                        [{"hovertemplate":"HA=%{x}\u003cbr\u003eCarb=%{y}\u003cbr\u003eDW=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.0009916721547541,0.0110928176401033,0.0303365127564972,0.5061126605155876,0.5056934729766942,0.000885883340053,0.5077294059012744,0.5039397084398847,0.5610034967947548,0.505914910557002,0.5817277162693093,0.0002141160599864
# ...
